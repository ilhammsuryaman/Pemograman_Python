# %% [markdown]
# <a href="https://colab.research.google.com/github/ilhammsuryaman/Pemograman_Python/blob/main/Pemograman%20Python_Tugas%2013_IlhamMsuryaman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
  #frek = frekuensi (MHz)
  #tipe = urban, suburban, open
  #ht = tinggi tower (meter)
  #hr = tinggi user (meter)
  #d = jarak (meter)
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
tower=80  
user=1.5 
dmin=200 
dmax=700 
N=200 
d=np.random.randint(dmin,dmax,N)

# %%
def Ruangx():
  f=1800 
  loc='urban'
  LpUrban=cos(f,loc,tower,user,d)
  d_sort=d[np.argsort(d)]
  Urban_sort=LpUrban[np.argsort(d)]
  return d_sort,Urban_sort

# %%
def Ruangy():
  f=1800 
  loc='open'
  LpUrban=cos(f,loc,tower,user,d)
  d_sort=d[np.argsort(d)]
  Urban_sort=LpUrban[np.argsort(d)]
  return d_sort,Urban_sort

# %%
def Ruangz():
  f=1800 
  loc='suburban'
  LpUrban=cos(f,loc,tower,user,d)
  d_sort=d[np.argsort(d)]
  Urban_sort=LpUrban[np.argsort(d)]
  return d_sort,Urban_sort

# %%
def frekuensix():
  f=700 
  loc='urban'
  LpUrban=cos(f,loc,tower,user,d)
  d_sort=d[np.argsort(d)]
  Urban_sort=LpUrban[np.argsort(d)]
  return d_sort,Urban_sort

# %%
def frekuensiy():
  f=900 
  loc='urban'
  LpUrban=cos(f,loc,tower,user,d)
  d_sort=d[np.argsort(d)]
  Urban_sort=LpUrban[np.argsort(d)]
  return d_sort,Urban_sort

# %%
def frekuensiz():
  f=1800 
  loc='urban'
  LpUrban=cos(f,loc,tower,user,d)
  d_sort=d[np.argsort(d)]
  Urban_sort=LpUrban[np.argsort(d)]
  return d_sort,Urban_sort

# %%
x1,y1 = Ruangx()
x2,y2 = Ruangy()
x3,y3 = Ruangz()

a1,b1 = frekuensix()
a2,b2 = frekuensiy()
a3,b3 = frekuensiz()

# %%
plt.figure()
plt.plot(x1,y1,'b', label='urban')
plt.plot(x2,y2,'g', label='open')
plt.plot(x3,y3,'r', label='suburban')
plt.legend()
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

plt.figure()
plt.plot(a1,b1,'c', label='700 Mhz')
plt.plot(a2,b2,'m', label='900 Mhz')
plt.plot(a3,b3,'y', label='1800 Mhz')
plt.legend()
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()
